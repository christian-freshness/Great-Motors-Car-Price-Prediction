# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Train.csv")
df2 = pd.read_csv('Test.csv')

# %%
df
# Out:
#      VehicleID Location          Maker                 Model   Year  Colour  \
# 0     VHL12546    Abuja          Honda   Accord Coupe EX V-6  2,011  Silver
# 1     VHL18827   Ibadan        Hyundai                Sonata  2,012  Silver
# 2     VHL19499    Lagos          Lexus                RX 350  2,010     Red
# 3     VHL17991    Abuja  Mercedes-Benz             GLE-Class  2,017    Blue
# 4     VHL12170   Ibadan         Toyota            Highlander  2,002     Red
# ...        ...      ...            ...                   ...    ...     ...
# 7200  VHL14329    Abuja          Honda                 Civic  2,018    Gray
# 7201  VHL10637    Abuja            BMW                    X3  2,007   White
# 7202  VHL19734    Abuja         Toyota  RAV4 2.5 Limited 4x4  2,010   Black
# 7203  VHL15569    Lagos  Mercedes-Benz         GLK-Class 350  2,012   Black
# 7204  VHL15246    Abuja          Honda      Accord Crosstour  2,012    Gray
#
#       Amount (Million Naira)           Type Distance
# ...

# %%
df2
# Out:
#      VehicleID Location    Maker                  Model   Year  Colour  \
# 0     VHL18518    Abuja      BMW                   323i  2,008   White
# 1     VHL17149    Lagos   Toyota                  Camry  2,013   White
# 2     VHL10927    Lagos   Toyota  Highlander Limited V6  2,005    Gold
# 3     VHL12909    Lagos   Toyota                  Camry  2,011    Gray
# 4     VHL12348    Lagos    Lexus             ES 350 FWD  2,013     Red
# ...        ...      ...      ...                    ...    ...     ...
# 2056  VHL17903    Abuja   Toyota                 Avalon  2,020     Red
# 2057  VHL14018   Ibadan     Audi                     Q5  2,011    Blue
# 2058  VHL17473   Ibadan   Toyota                  Camry  2,015   Black
# 2059  VHL11480    Abuja    Lexus             IS 350 AWD  2,013   White
# 2060  VHL13881    Abuja  Pontiac                Torrent  2,009  Silver
#
#               Type  Distance
# 0     Foreign Used   30524.0
# 1     Foreign Used       NaN
# ...

# %%
sub_file = pd.DataFrame(columns=['VehicleID', 'Amount (Million Naira)'])
sub_file.VehicleID = df2.VehicleID
sub_file.head()
# Out:
#   VehicleID Amount (Million Naira)
# 0  VHL18518                    NaN
# 1  VHL17149                    NaN
# 2  VHL10927                    NaN
# 3  VHL12909                    NaN
# 4  VHL12348                    NaN

# %%
type(df.Year)
# Out:
# pandas.core.series.Series

# %%
df.Year.dtype
# Out:
# dtype('O')

# %%
df["Year"] = df.Year.str.replace(',', '')
df2["Year"] = df2.Year.str.replace(',', '')

# %%
df.head()
# Out:
#   VehicleID Location          Maker                Model  Year  Colour  \
# 0  VHL12546    Abuja          Honda  Accord Coupe EX V-6  2011  Silver
# 1  VHL18827   Ibadan        Hyundai               Sonata  2012  Silver
# 2  VHL19499    Lagos          Lexus               RX 350  2010     Red
# 3  VHL17991    Abuja  Mercedes-Benz            GLE-Class  2017    Blue
# 4  VHL12170   Ibadan         Toyota           Highlander  2002     Red
#
#    Amount (Million Naira)           Type Distance
# 0                     2.2  Nigerian Used      NaN
# 1                     3.5  Nigerian Used  125,000
# 2                     9.2   Foreign Used  110,852
# 3                    22.8   Foreign Used   30,000
# 4                     2.6  Nigerian Used  125,206

# %%
df2.head()
# Out:
#   VehicleID Location   Maker                  Model  Year Colour  \
# 0  VHL18518    Abuja     BMW                   323i  2008  White
# 1  VHL17149    Lagos  Toyota                  Camry  2013  White
# 2  VHL10927    Lagos  Toyota  Highlander Limited V6  2005   Gold
# 3  VHL12909    Lagos  Toyota                  Camry  2011   Gray
# 4  VHL12348    Lagos   Lexus             ES 350 FWD  2013    Red
#
#            Type  Distance
# 0  Foreign Used   30524.0
# 1  Foreign Used       NaN
# 2  Foreign Used       NaN
# 3  Foreign Used  166839.0
# 4  Foreign Used   88862.0

# %%
df.isna().sum()
# Out:
# VehicleID                    0
# Location                     0
# Maker                        0
# Model                        0
# Year                        21
# Colour                       0
# Amount (Million Naira)      17
# Type                       197
# Distance                  2360
# dtype: int64

# %%
df2.isna().sum()
# Out:
# VehicleID      0
# Location       0
# Maker          0
# Model          0
# Year           2
# Colour         0
# Type          54
# Distance     676
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7184 non-null   object
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7188 non-null   float64
#  7   Type                    7008 non-null   object
#  8   Distance                4845 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 506.7+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VehicleID  2061 non-null   object
#  1   Location   2061 non-null   object
#  2   Maker      2061 non-null   object
#  3   Model      2061 non-null   object
#  4   Year       2059 non-null   object
#  5   Colour     2061 non-null   object
#  6   Type       2007 non-null   object
#  7   Distance   1385 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 128.9+ KB

# %%
# Handling the missing values for df

df['Year'].fillna((df['Year'].median()), inplace=True)

df['Amount (Million Naira)'].fillna((df['Amount (Million Naira)'].median()), inplace=True)

df['Type'].fillna(method='ffill', inplace=True)

df["Distance"] = df.Distance.str.replace(',', '')

df['Distance'].fillna((df['Distance'].median()), inplace=True)

print(df.Distance.dtype)
print(type(df.Distance))
# Out:
# object
# <class 'pandas.core.series.Series'>

# %%
# Handling the missing values for df2

df2['Year'].fillna((df2['Year'].median()), inplace=True)

df2['Type'].fillna(method='ffill', inplace=True)

df2['Distance'].fillna((df2['Distance'].median()), inplace=True)

# %%
df.isna().sum()
# Out:
# VehicleID                 0
# Location                  0
# Maker                     0
# Model                     0
# Year                      0
# Colour                    0
# Amount (Million Naira)    0
# Type                      0
# Distance                  0
# dtype: int64

# %%
df2.isna().sum()
# Out:
# VehicleID    0
# Location     0
# Maker        0
# Model        0
# Year         0
# Colour       0
# Type         0
# Distance     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7205 non-null   object
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7205 non-null   float64
#  7   Type                    7205 non-null   object
#  8   Distance                7205 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 506.7+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VehicleID  2061 non-null   object
#  1   Location   2061 non-null   object
#  2   Maker      2061 non-null   object
#  3   Model      2061 non-null   object
#  4   Year       2061 non-null   object
#  5   Colour     2061 non-null   object
#  6   Type       2061 non-null   object
#  7   Distance   2061 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 128.9+ KB

# %%
df
# Out:
#      VehicleID Location          Maker                 Model  Year  Colour  \
# 0     VHL12546    Abuja          Honda   Accord Coupe EX V-6  2011  Silver
# 1     VHL18827   Ibadan        Hyundai                Sonata  2012  Silver
# 2     VHL19499    Lagos          Lexus                RX 350  2010     Red
# 3     VHL17991    Abuja  Mercedes-Benz             GLE-Class  2017    Blue
# 4     VHL12170   Ibadan         Toyota            Highlander  2002     Red
# ...        ...      ...            ...                   ...   ...     ...
# 7200  VHL14329    Abuja          Honda                 Civic  2018    Gray
# 7201  VHL10637    Abuja            BMW                    X3  2007   White
# 7202  VHL19734    Abuja         Toyota  RAV4 2.5 Limited 4x4  2010   Black
# 7203  VHL15569    Lagos  Mercedes-Benz         GLK-Class 350  2012   Black
# 7204  VHL15246    Abuja          Honda      Accord Crosstour  2012    Gray
#
#       Amount (Million Naira)           Type Distance
# ...

# %%
df2
# Out:
#      VehicleID Location    Maker                  Model  Year  Colour  \
# 0     VHL18518    Abuja      BMW                   323i  2008   White
# 1     VHL17149    Lagos   Toyota                  Camry  2013   White
# 2     VHL10927    Lagos   Toyota  Highlander Limited V6  2005    Gold
# 3     VHL12909    Lagos   Toyota                  Camry  2011    Gray
# 4     VHL12348    Lagos    Lexus             ES 350 FWD  2013     Red
# ...        ...      ...      ...                    ...   ...     ...
# 2056  VHL17903    Abuja   Toyota                 Avalon  2020     Red
# 2057  VHL14018   Ibadan     Audi                     Q5  2011    Blue
# 2058  VHL17473   Ibadan   Toyota                  Camry  2015   Black
# 2059  VHL11480    Abuja    Lexus             IS 350 AWD  2013   White
# 2060  VHL13881    Abuja  Pontiac                Torrent  2009  Silver
#
#               Type  Distance
# 0     Foreign Used   30524.0
# 1     Foreign Used   82000.0
# 2     Foreign Used   82000.0
# ...

# %%
from collections import Counter

# %%
Counter(df['Location'])
# Out:
# Counter({'Abuja': 3263, 'Ibadan': 624, 'Lagos': 3318})

# %%
Counter(df['Maker'])
# Out:
# Counter({'Honda': 358,
#          'Hyundai': 162,
#          'Lexus': 1599,
#          'Mercedes-Benz': 1213,
#          'Toyota': 2742,
#          'Acura': 154,
#          'Dodge': 24,
#          'Nissan': 101,
#          'Kia': 66,
#          'BMW': 111,
#          'Volvo': 7,
#          'Ford': 120,
#          'Land Rover': 124,
#          'Lincoln': 6,
#          'Peugeot': 75,
#          'Chevrolet': 21,
#          'Audi': 23,
#          'Jaguar': 12,
#          'Infiniti': 18,
#          'Porsche': 7,
#          'Fiat': 3,
#          'Maserati': 6,
#          'Volkswagen': 54,
#          'Suzuki': 8,
#          'Bentley': 6,
#          'GAC': 3,
#          'Mazda': 28,
#          'Scion': 7,
#          'Renault': 3,
#          'Mitsubishi': 23,
#          'Mini': 9,
#          'Pontiac': 30,
#          'Cadillac': 7,
#          'Ferrari': 1,
#          'Jeep': 18,
#          'Buick': 5,
#          'Rolls-Royce': 10,
#          'GMC': 8,
#          'Chrysler': 4,
# ...

# %%
Counter(df['Year'])
# Out:
# Counter({'2011': 455,
#          '2012': 460,
#          '2010': 618,
#          '2017': 291,
#          '2002': 74,
#          '2019': 189,
#          '2015': 369,
#          '2004': 222,
#          '2003': 122,
#          '2008': 755,
#          '2018': 269,
#          '2020': 204,
#          '2006': 349,
#          '2016': 280,
#          '2014': 412,
#          '2007': 484,
#          '2009': 439,
#          '2005': 298,
#          '2021': 145,
#          '2013': 599,
#          '2000': 39,
#          2011.0: 21,
#          '1992': 3,
#          '2001': 55,
#          '1997': 5,
#          '1999': 19,
#          '1993': 1,
#          '1998': 11,
#          '1986': 2,
#          '1996': 1,
#          '2022': 10,
#          '1995': 2,
#          '1979': 1,
#          '1989': 1})

# %%
Counter(df['Type'])
# Out:
# Counter({'Nigerian Used': 1945, 'Foreign Used': 5034, 'Brand New': 226})

# %%
Counter(df['Colour'])
# Out:
# Counter({'Silver': 1123,
#          'Red': 478,
#          'Blue': 554,
#          'Black': 2128,
#          'Gold': 357,
#          'White': 1019,
#          'Gray': 1152,
#          'Burgandy': 27,
#          'Green': 179,
#          'Violet': 1,
#          'Brown': 114,
#          'Yellow': 7,
#          'Orange': 11,
#          'Pink': 7,
#          'Beige': 25,
#          'Purple': 16,
#          'Ivory': 3,
#          'G': 1,
#          'Teal': 1,
#          'Mica': 1,
#          'Pearl': 1})

# %%
df['Distance'] = df.Distance.astype(float)
df['Year'] = df.Year.astype(int)
df2['Year'] = df2.Year.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7205 entries, 0 to 7204
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   VehicleID               7205 non-null   object
#  1   Location                7205 non-null   object
#  2   Maker                   7205 non-null   object
#  3   Model                   7205 non-null   object
#  4   Year                    7205 non-null   int32
#  5   Colour                  7205 non-null   object
#  6   Amount (Million Naira)  7205 non-null   float64
#  7   Type                    7205 non-null   object
#  8   Distance                7205 non-null   float64
# dtypes: float64(2), int32(1), object(6)
# memory usage: 478.6+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2061 entries, 0 to 2060
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   VehicleID  2061 non-null   object
#  1   Location   2061 non-null   object
#  2   Maker      2061 non-null   object
#  3   Model      2061 non-null   object
#  4   Year       2061 non-null   int32
#  5   Colour     2061 non-null   object
#  6   Type       2061 non-null   object
#  7   Distance   2061 non-null   float64
# dtypes: float64(1), int32(1), object(6)
# memory usage: 120.9+ KB

# %%
df
# Out:
#      VehicleID Location          Maker                 Model  Year  Colour  \
# 0     VHL12546    Abuja          Honda   Accord Coupe EX V-6  2011  Silver
# 1     VHL18827   Ibadan        Hyundai                Sonata  2012  Silver
# 2     VHL19499    Lagos          Lexus                RX 350  2010     Red
# 3     VHL17991    Abuja  Mercedes-Benz             GLE-Class  2017    Blue
# 4     VHL12170   Ibadan         Toyota            Highlander  2002     Red
# ...        ...      ...            ...                   ...   ...     ...
# 7200  VHL14329    Abuja          Honda                 Civic  2018    Gray
# 7201  VHL10637    Abuja            BMW                    X3  2007   White
# 7202  VHL19734    Abuja         Toyota  RAV4 2.5 Limited 4x4  2010   Black
# 7203  VHL15569    Lagos  Mercedes-Benz         GLK-Class 350  2012   Black
# 7204  VHL15246    Abuja          Honda      Accord Crosstour  2012    Gray
#
#       Amount (Million Naira)           Type  Distance
# ...

# %%
df2
# Out:
#      VehicleID Location    Maker                  Model  Year  Colour  \
# 0     VHL18518    Abuja      BMW                   323i  2008   White
# 1     VHL17149    Lagos   Toyota                  Camry  2013   White
# 2     VHL10927    Lagos   Toyota  Highlander Limited V6  2005    Gold
# 3     VHL12909    Lagos   Toyota                  Camry  2011    Gray
# 4     VHL12348    Lagos    Lexus             ES 350 FWD  2013     Red
# ...        ...      ...      ...                    ...   ...     ...
# 2056  VHL17903    Abuja   Toyota                 Avalon  2020     Red
# 2057  VHL14018   Ibadan     Audi                     Q5  2011    Blue
# 2058  VHL17473   Ibadan   Toyota                  Camry  2015   Black
# 2059  VHL11480    Abuja    Lexus             IS 350 AWD  2013   White
# 2060  VHL13881    Abuja  Pontiac                Torrent  2009  Silver
#
#               Type  Distance
# 0     Foreign Used   30524.0
# 1     Foreign Used   82000.0
# 2     Foreign Used   82000.0
# ...

# %%
df.drop(['VehicleID'], axis=1, inplace=True)
df2.drop(['VehicleID'], axis=1, inplace=True)

# %%
df.head(2)
# Out:
#   Location    Maker                Model  Year  Colour  \
# 0    Abuja    Honda  Accord Coupe EX V-6  2011  Silver
# 1   Ibadan  Hyundai               Sonata  2012  Silver
#
#    Amount (Million Naira)           Type  Distance
# 0                     2.2  Nigerian Used   80830.0
# 1                     3.5  Nigerian Used  125000.0

# %%
df2.head(2)
# Out:
#   Location   Maker  Model  Year Colour          Type  Distance
# 0    Abuja     BMW   323i  2008  White  Foreign Used   30524.0
# 1    Lagos  Toyota  Camry  2013  White  Foreign Used   82000.0

# %% [markdown]
# ## MODELLING

# %%
categ_col = df.select_dtypes(include=['object', 'category']).columns

num_cols = [col for col in df.columns if col not in categ_col]
print(categ_col)
# Out:
# Index(['Location', 'Maker', 'Model', 'Colour', 'Type'], dtype='object')

# %%
print(num_cols)
# Out:
# ['Year', 'Amount (Million Naira)', 'Distance']

# %%
# label encoding
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

le = LabelEncoder()
for i in categ_col:
    df[i] = le.fit_transform(df[i])
    df2[i] = le.fit_transform(df2[i])

# %%
df.head()
# Out:
#    Location  Maker  Model  Year  Colour  Amount (Million Naira)  Type  \
# 0         0     17    117  2011      16                     2.2     2
# 1         1     19   1049  2012      16                     3.5     2
# 2         2     29    908  2010      15                     9.2     1
# 3         0     34    508  2017       2                    22.8     1
# 4         1     52    569  2002      15                     2.6     2
#
#    Distance
# 0   80830.0
# 1  125000.0
# 2  110852.0
# 3   30000.0
# 4  125206.0

# %%
df2.head()
# Out:
#    Location  Maker  Model  Year  Colour  Type  Distance
# 0         0      2      8  2008      16     1   30524.0
# 1         2     37    123  2013      16     1   82000.0
# 2         2     37    272  2005       7     1   82000.0
# 3         2     37    123  2011       8     1  166839.0
# 4         2     20    192  2013      12     1   88862.0

# %%
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Ridge
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# splitting the data into X and y
x = df.drop('Amount (Million Naira)', axis = 1)
y = df['Amount (Million Naira)']

# %%
# splitting data into train and test set

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((5764, 7), (5764,), (1441, 7), (1441,))

# %%
# putting models in a dictionary
models = {"XGBoost Regressor": XGBRegressor(),
          "DecisionTree Regressor": DecisionTreeRegressor(),
          "Random Forest": RandomForestRegressor(),
          "Catboost": CatBoostRegressor(),
          "gradientboosting": GradientBoostingRegressor(),
          "KNeighborsRegressor": KNeighborsRegressor(),
          "Ridge": Ridge(),
          "SVR": SVR(),
          "LinearRegression": LinearRegression(),
         }

# setting up a function to fit and score model
def fit_and_score(models, X_train, X_test, y_train, y_test):
    """
    fits and evaluates given machine learning models
    models: a dictionary of different scikit learn machine learning models
    X_train: training data (no labels)
    X_test: testing data(no labels)
    y_train: training labels
    y_test: testing labels
    """
    #setting up a random seed
    np.random.seed(42)
    
    # making a dictionary to keep model scores
    model_scores = {}
    
    #looping through models
    for name, model in models.items():
        #fitting the model to the data
        model.fit(x_train, y_train)
        # evaluating the model and appending its score to model_scores
        model_scores[name] = model.score(x_test, y_test)
    return model_scores

# %%
# %%time
scores = fit_and_score(models=models,
                             X_train=x_train,
                             X_test=x_test,
                             y_train=y_train,
                             y_test=y_test)
scores
# Out:
# Learning rate set to 0.05331
# 0:	learn: 24.3080866	total: 226ms	remaining: 3m 45s
# 1:	learn: 23.7125008	total: 236ms	remaining: 1m 57s
# 2:	learn: 23.1342085	total: 246ms	remaining: 1m 21s
# 3:	learn: 22.6098588	total: 255ms	remaining: 1m 3s
# 4:	learn: 22.0914149	total: 259ms	remaining: 51.5s
# 5:	learn: 21.5964993	total: 263ms	remaining: 43.6s
# 6:	learn: 21.1638584	total: 267ms	remaining: 37.9s
# 7:	learn: 20.7274837	total: 271ms	remaining: 33.6s
# 8:	learn: 20.3088101	total: 275ms	remaining: 30.3s
# 9:	learn: 19.9374222	total: 279ms	remaining: 27.6s
# 10:	learn: 19.5731846	total: 283ms	remaining: 25.4s
# 11:	learn: 19.2162217	total: 287ms	remaining: 23.6s
# 12:	learn: 18.9250525	total: 291ms	remaining: 22.1s
# 13:	learn: 18.6131685	total: 295ms	remaining: 20.7s
# 14:	learn: 18.3386200	total: 299ms	remaining: 19.6s
# 15:	learn: 18.0609105	total: 303ms	remaining: 18.6s
# 16:	learn: 17.8178601	total: 306ms	remaining: 17.7s
# 17:	learn: 17.5473016	total: 310ms	remaining: 16.9s
# ...

# %%
model_compare = pd.DataFrame(scores, index=['R2_Score'])
model_compare.T.plot.bar();# T means transpose, so as to improve the plot

# %%
# %%time
cbt_model = CatBoostRegressor(n_estimators=3600,
                         learning_rate=0.15,random_state=42,
                         depth=2)

cbt_model.fit(x_train, y_train)
# Out:
# 0:	learn: 23.8297198	total: 4.64ms	remaining: 16.7s
# 1:	learn: 22.7836442	total: 8.26ms	remaining: 14.9s
# 2:	learn: 21.8597373	total: 12.4ms	remaining: 14.9s
# 3:	learn: 21.1257597	total: 16.2ms	remaining: 14.6s
# 4:	learn: 20.4177793	total: 19.9ms	remaining: 14.3s
# 5:	learn: 19.8893355	total: 23.5ms	remaining: 14.1s
# 6:	learn: 19.4892556	total: 25.6ms	remaining: 13.1s
# 7:	learn: 19.1447675	total: 27.6ms	remaining: 12.4s
# 8:	learn: 18.8182175	total: 29.7ms	remaining: 11.8s
# 9:	learn: 18.5579531	total: 31.7ms	remaining: 11.4s
# 10:	learn: 18.3573358	total: 33.7ms	remaining: 11s
# 11:	learn: 18.1146828	total: 35.6ms	remaining: 10.6s
# 12:	learn: 17.9526723	total: 37.5ms	remaining: 10.4s
# 13:	learn: 17.8253277	total: 39.3ms	remaining: 10.1s
# 14:	learn: 17.5587684	total: 41ms	remaining: 9.8s
# 15:	learn: 17.4398097	total: 42.7ms	remaining: 9.57s
# 16:	learn: 17.2849067	total: 44.6ms	remaining: 9.4s
# 17:	learn: 17.2108275	total: 46.3ms	remaining: 9.22s
# ...

# %%
cbt_model.score(x_test, y_test)
# Out:
# 0.8906323628529124

# %%
# %%time
xbt_model = XGBRegressor(n_estimators=1000,
                         learning_rate=0.05,random_state=42,
                         )

xbt_model.fit(x_train, y_train)
# Out:
# Wall time: 4.51 s
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=1000, n_jobs=0, num_parallel_tree=1, random_state=42,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xbt_model.score(x_test, y_test)
# Out:
# 0.8984582252718001

# %%
# making predictions
y_preds = cbt_model.predict(x_test)
y_preds
# Out:
# array([11.71900768, 11.69911627, 52.89262759, ...,  0.90871604,
#        12.32340847,  9.29236974])

# %%
# making predictions
y_preds2 = xbt_model.predict(x_test)
y_preds2
# Out:
# array([ 6.706067 , 12.761675 , 50.74559  , ...,  1.172391 ,  4.501526 ,
#         6.7407737], dtype=float32)

# %%
sub = pd.DataFrame(columns=['predicted', 'Amount (Million Naira)'])
sub.predicted, sub['Amount (Million Naira)'] = y_preds, df['Amount (Million Naira)']
sub
# Out:
#       predicted  Amount (Million Naira)
# 0     11.719008                    2.20
# 1     11.699116                    3.50
# 2     52.892628                    9.20
# 3      3.138323                   22.80
# 4     12.229980                    2.60
# ...         ...                     ...
# 1436  20.957840                   12.38
# 1437   7.531293                    2.60
# 1438   0.908716                   16.50
# 1439  12.323408                   13.50
# 1440   9.292370                    4.00
#
# [1441 rows x 2 columns]

# %%
sub2 = pd.DataFrame(columns=['predicted', 'Amount (Million Naira)'])
sub2.predicted, sub2['Amount (Million Naira)'] = y_preds2, df['Amount (Million Naira)']
sub2
# Out:
#       predicted  Amount (Million Naira)
# 0      6.706067                    2.20
# 1     12.761675                    3.50
# 2     50.745590                    9.20
# 3      2.964674                   22.80
# 4     25.508478                    2.60
# ...         ...                     ...
# 1436  48.832577                   12.38
# 1437   7.074360                    2.60
# 1438   1.172391                   16.50
# 1439   4.501526                   13.50
# 1440   6.740774                    4.00
#
# [1441 rows x 2 columns]

# %%
# Root Mean squared error

mse = mean_squared_error(y_test, y_preds)
np.sqrt(mse)
# Out:
# 8.787830060928362

# %%
# Root Mean squared error

mse2 = mean_squared_error(y_test, y_preds2)
np.sqrt(mse2)
# Out:
# 8.467585880284117

# %%
test_preds = cbt_model.predict(df2)
test_preds
# Out:
# array([7.56755555, 5.64364649, 0.73031861, ..., 7.81087752, 4.54395015,
#        4.51853315])

# %%
test_preds2 = xbt_model.predict(df2)
test_preds2
# Out:
# array([5.0364313, 5.0562034, 2.496192 , ..., 7.969162 , 5.5992427,
#        4.5522823], dtype=float32)

# %%
sub_file['Amount (Million Naira)'] = test_preds
sub_file
# Out:
#      VehicleID  Amount (Million Naira)
# 0     VHL18518                7.567556
# 1     VHL17149                5.643646
# 2     VHL10927                0.730319
# 3     VHL12909                4.089748
# 4     VHL12348                7.007472
# ...        ...                     ...
# 2056  VHL17903               46.728709
# 2057  VHL14018                4.751325
# 2058  VHL17473                7.810878
# 2059  VHL11480                4.543950
# 2060  VHL13881                4.518533
#
# [2061 rows x 2 columns]

# %%
sub_file2 = pd.DataFrame(columns=['VehicleID', 'Amount (Million Naira)'])
sub_file2.VehicleID = sub_file.VehicleID
sub_file2['Amount (Million Naira)'] = test_preds2
sub_file2
# Out:
#      VehicleID  Amount (Million Naira)
# 0     VHL18518                5.036431
# 1     VHL17149                5.056203
# 2     VHL10927                2.496192
# 3     VHL12909                2.553403
# 4     VHL12348                5.925097
# ...        ...                     ...
# 2056  VHL17903               26.428818
# 2057  VHL14018               10.093079
# 2058  VHL17473                7.969162
# 2059  VHL11480                5.599243
# 2060  VHL13881                4.552282
#
# [2061 rows x 2 columns]

# %%
#sub_file.to_csv('submission1.csv', index=False)

# %%
#sub_file2.to_csv('submission2.csv', index=False)

# %%
r_model.score(x_test, y_test)
# Out:
# 0.8238891483289643

# %%
# making predictions
y_preds3 = r_model.predict(x_test)
y_preds3
# Out:
# array([ 4.28166333, 13.7203    , 49.44139524, ...,  1.3942    ,
#         4.632275  ,  5.42048833])

# %%
# Root Mean squared error

mse3 = mean_squared_error(y_test, y_preds3)
np.sqrt(mse3)
# Out:
# 11.151423101288739

# %%
test_preds3 = r_model.predict(df2)
test_preds3
# Out:
# array([2.55295   , 4.8916245 , 2.584005  , ..., 8.92484   , 6.86242036,
#        5.8212    ])

# %%
sub_file3 = pd.DataFrame(columns=['VehicleID', 'Amount (Million Naira)'])
sub_file3.VehicleID = sub_file.VehicleID
sub_file3['Amount (Million Naira)'] = test_preds3
sub_file3.head()
# Out:
#   VehicleID  Amount (Million Naira)
# 0  VHL18518                2.552950
# 1  VHL17149                4.891625
# 2  VHL10927                2.584005
# 3  VHL12909                4.055538
# 4  VHL12348                5.336966

# %%
#sub_file3.to_csv('submission3.csv', index=False)

# %%
# %%time
g_model = GradientBoostingRegressor(n_estimators=3600,
                         learning_rate=0.15,random_state=42,
                         )

g_model.fit(x_train, y_train)
g_model.score(x_test, y_test)
# Out:
# Wall time: 28.1 s
# 0.8666161666239879

# %%
# making predictions
y_preds4 = g_model.predict(x_test)
y_preds4
# Out:
# array([ 7.97929946, 12.3635157 , 49.82851786, ...,  1.22245591,
#         5.93071432,  6.41936888])

# %%
# Root Mean squared error

mse4 = mean_squared_error(y_test, y_preds4)
np.sqrt(mse4)
# Out:
# 9.70485011872036

# %%
test_preds4 = g_model.predict(df2)
test_preds4
# Out:
# array([11.14265528,  6.0740022 ,  2.17186125, ...,  8.44253141,
#         5.62494749,  5.07827846])

# %%
sub_file4 = pd.DataFrame(columns=['VehicleID', 'Amount (Million Naira)'])
sub_file4.VehicleID = sub_file.VehicleID
sub_file4['Amount (Million Naira)'] = test_preds4
sub_file4.head()
# Out:
#   VehicleID  Amount (Million Naira)
# 0  VHL18518               11.142655
# 1  VHL17149                6.074002
# 2  VHL10927                2.171861
# 3  VHL12909                3.860733
# 4  VHL12348                9.374554

# %%
#sub_file4.to_csv('submission4.csv', index=False)

# %%
xbt_model.feature_importances_
# Out:
# array([0.02025494, 0.21790196, 0.12111618, 0.38460332, 0.03629168,
#        0.20363845, 0.01619349], dtype=float32)

# %%
# creating a function for visualing the feature importances
import seaborn as sns
def plot_importances(columns, importances, n=20):
    df6 = (pd.DataFrame({'features': columns,
                        'feature_importances': importances})
                       .sort_values('feature_importances', ascending=False)
                       .reset_index(drop=False))

    # plotting the dataframe
    fig, ax = plt.subplots(figsize=(10,8))
    ax = sns.barplot(x = 'feature_importances', y = 'features', data = df6[:n], orient='h')
    plt.ylabel('features')
    plt.xlabel('feature_importances')

# %%
plot_importances(x_train.columns, best_model.feature_importances_)

# %% [markdown]
# # THANK YOU!!
